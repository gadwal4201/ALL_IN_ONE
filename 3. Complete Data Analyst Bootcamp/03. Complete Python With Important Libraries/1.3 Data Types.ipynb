# %% [markdown]
# # Data Types

# %% [markdown]
# 1. Definition :
#
# -> Data Types are a classification of data which tell the compiler or interpreter how the programmer intends to use the data.
#
# -> They determine the type of operations that can be performed on the data, the values that the data can take, and the amount of memory needed to store the data

# %% [markdown]
# 2. Importance of Data Types in Programming
#
# -> Data types enure that data is stored in an efficient way.
#
# -> They help in performing correct operations on data.
#
# -> Proper use of data  types can prevent errors and bugs in the program.

# %% [markdown]
# # 1. Integer Data Type

# %%
age = 22
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# # 2. Float Data type

# %%
height = 5.9
print(type(height))
# Out:
# <class 'float'>

# %% [markdown]
# # 3. String Data Type

# %%
name = "Pankaj"
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# # 4. Boolean Data Type

# %%
is_true = True
print(type(is_true))
# Out:
# <class 'bool'>

# %%
is_true = bool(True) # By default it gives False
print(is_true)
# Out:
# True

# %% [markdown]
# Common Errors

# %%
result = "5" + 4
print(result)

# For this you have to use type casting
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 result = "5" + 4
#       2 print(result)
#       3
#       4 # For this you have to use type casting
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # type Casting

# %%
result = int("5") + 4
print(result)

result = "5" + str(4)
print(result)
# Out:
# 9
# 54
